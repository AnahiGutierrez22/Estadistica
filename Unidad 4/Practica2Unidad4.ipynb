# %% [markdown]
# <a href="https://colab.research.google.com/github/AnahiGutierrez22/Estadistica/blob/main/Unidad%204/Practica2Unidad4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# ##Probabilidad y estadistica
# Unidad 4
#
# Distribución de probabilidades
#
# Distribución binomial
#
# Facilitador: Dr. Jose Gabriel Rodriguez Rivas
#
# Alumna: Anahí Gutiérrez López

# %%
from scipy.stats import binom
# parametros de la distribucion binomial
probabilidad_exito = 0.83
num_pacientes = 16
X= 0
#Calcular la probabilidad de que ningun paciente sufra la enfermedad
probabilidad_ninguno_enfermo = binom.pmf(X, num_pacientes, probabilidad_exito)
print ("La probabilidad de que ningun paciente sufra la enfermedad es : ", probabilidad_ninguno_enfermo)
# Out:
# La probabilidad de que ningun paciente sufra la enfermedad es :  4.866119187566701e-13

# %%
from scipy.stats import binom
# parametros de la distribucion binomial
probabilidad_exito = 0.83
num_pacientes = 16
X= 16
#Calcular la probabilidad de que todos  paciente sufra la enfermedad
probabilidad_todos_enfermo = binom.pmf(X, num_pacientes, probabilidad_exito)
print ("La probabilidad de que todos los pacienten sufran la enfermedad es : ", probabilidad_todos_enfermo)
# Out:
# La probabilidad de que todos los pacienten sufran la enfermedad es :  0.0507282029895386

# %% [markdown]
# ##Ejercicio 2
#
# Para una variable aleatoria binomial con n = 10 y una probabilidad de 0.10
# Encontrar la probabilidad de la variable aleatoria x = 2 Realizar un programa en python que resuelva el problema usando una distribucion de probabilidad binomial
# Fuente: libro de Introduccion a la probabilidad, pag. 187

# %%
from scipy.stats import binom
#Parámetros de la distribución binomial
n = 10
p = 0.10
x = 2
#Calcular la probabilidad de La variable aleatoria x = 2
probabilidad_x_2 = binom.pmf(x, n, p)
print("La probabilidad de que la variable aleatoria X sea igual a 2 es:", probabilidad_x_2)

# %% [markdown]
# ##Ejercicio 3
#
# Para una variable aleatoria binomial con n =10 y una probabilidad de 0.10.
# Calcular las probabilidades para cada valor de x = 0 hasta 10.
# • Imprimir la tabla de valores de x y sus probabilidades.
# Graficar el histograma de la distribución binomial
# Fuente: libro de Introduccion a la probabilidad, pag. 187

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import binom
#Parámetros de la distribución binomial
n = 10
p = 0.10
#Calcular Las probabilidades para cada valor de x de 0 a 10
valores_x = np.arange(0, n+1)
probabilidades_x= [binom.pmf(x, n, p) for x in valores_x]

#Imprimir La tabla de valores de x y sus probabilidades
print("Valores de x\tProbabilidades")
for x, probabilidad in zip(valores_x, probabilidades_x):
   print(f"{x}\t\t{probabilidad}")

# %%
# Graficar el histograma de la distribución binomial
plt.figure(figsize=(8, 6))
plt.bar(valores_x, probabilidades_x, color='skyblue")
plt.title('Distribución Binomial')
plt.xlabel('Valor de X')
plt.ylabel('Probabilidad')
plt.xticks (valores_x)
plt.grid(True)
plt.show()
