# %% [markdown]
# <a href="https://colab.research.google.com/github/AnahiGutierrez22/Estadistica/blob/main/Unidad1/Practica4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# ## Probabilidad y estadistica
#
# Unidad 1
#
# Practica 4. Tablas de frecuencia
#
# Facilitador: Dr. José Gabriel Rodriguez Rivas
#
# Alumna: Anahí Gutiérrez López

# %%
import random

# %%
# lista, vector que representa la edad de 100 personas
edades =[]
# ciclo  para generar numeros aleatorios
for i in range (100):
  #generar el numero aleatorio con la funcion randit y se guarda en la variable numero_aleatorio
  numero_aleatorio= random.randint(18, 70)
# Agreganos el numero aleatorio a la lista de valores
  edades.append(numero_aleatorio)
print (edades)
# Out:
# [30, 18, 39, 65, 54, 55, 69, 55, 27, 53, 29, 48, 21, 46, 40, 57, 33, 60, 48, 46, 19, 66, 58, 61, 57, 70, 55, 23, 59, 26, 41, 24, 64, 70, 70, 52, 23, 40, 37, 41, 70, 23, 60, 24, 30, 32, 49, 23, 30, 56, 21, 55, 24, 68, 40, 36, 57, 49, 53, 39, 30, 21, 55, 59, 54, 26, 53, 42, 21, 34, 54, 31, 19, 34, 56, 26, 22, 37, 22, 28, 22, 55, 45, 35, 23, 58, 51, 48, 35, 69, 43, 50, 64, 60, 55, 70, 69, 27, 47, 54]

# %%
#libreria para datos
import pandas as pd

# %%
df= pd.DataFrame(edades, columns=['Edad'])
df.head()
# Out:
#    Edad
# 0    30
# 1    18
# 2    39
# 3    65
# 4    54

# %%
# calcular la tabla de distribucion de frecuencias

tabla_frecuencias = df['Edad'].value_counts().reset_index()
tabla_frecuencias.columns = ['Edad', 'Frecuencia']
tabla_frecuencias  = tabla_frecuencias.sort_values(by='Edad')

# imprimir tabla de distribucion
print("Tabla de distribución de frecuencias: ")
tabla_frecuencias
# Out:
# Tabla de distribución de frecuencias:
#     Edad  Frecuencia
# 28    18           1
# 25    19           2
# 5     21           4
# 11    22           3
# 2     23           5
# 8     24           3
# 7     26           3
# 23    27           2
# 33    28           1
# 40    29           1
# 4     30           4
# 35    31           1
# 41    32           1
# 42    33           1
# 21    34           2
# 16    35           2
# 36    36           1
# 17    37           2
# 26    39           2
# 14    40           3
# 20    41           2
# 37    42           1
# 30    43           1
# 32    45           1
# 27    46           2
# 45    47           1
# 12    48           3
# 15    49           2
# 29    50           1
# 31    51           1
# 43    52           1
# 13    53           3
# 3     54           4
# 0     55           7
# 18    56           2
# 10    57           3
# 24    58           2
# 22    59           2
# 9     60           3
# 38    61           1
# ...

# %%
tabla_frecuencias['Frec Relativa']= tabla_frecuencias ['Frecuencia']/ 100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa
# 28    18           1           0.01
# 25    19           2           0.02
# 5     21           4           0.04
# 11    22           3           0.03
# 2     23           5           0.05
# 8     24           3           0.03
# 7     26           3           0.03
# 23    27           2           0.02
# 33    28           1           0.01
# 40    29           1           0.01
# 4     30           4           0.04
# 35    31           1           0.01
# 41    32           1           0.01
# 42    33           1           0.01
# 21    34           2           0.02
# 16    35           2           0.02
# 36    36           1           0.01
# 17    37           2           0.02
# 26    39           2           0.02
# 14    40           3           0.03
# 20    41           2           0.02
# 37    42           1           0.01
# 30    43           1           0.01
# 32    45           1           0.01
# 27    46           2           0.02
# ...

# %%
tabla_frecuencias['Frec Porcentual']= tabla_frecuencias['Frecuencia']/100 * 100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa  Frec Porcentual
# 28    18           1           0.01              1.0
# 25    19           2           0.02              2.0
# 5     21           4           0.04              4.0
# 11    22           3           0.03              3.0
# 2     23           5           0.05              5.0
# 8     24           3           0.03              3.0
# 7     26           3           0.03              3.0
# 23    27           2           0.02              2.0
# 33    28           1           0.01              1.0
# 40    29           1           0.01              1.0
# 4     30           4           0.04              4.0
# 35    31           1           0.01              1.0
# 41    32           1           0.01              1.0
# 42    33           1           0.01              1.0
# 21    34           2           0.02              2.0
# 16    35           2           0.02              2.0
# 36    36           1           0.01              1.0
# ...

# %%
# cumsum para calcular la suma acumulada
tabla_frecuencias['Frec Acumulada']= tabla_frecuencias['Frecuencia'].cumsum()
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa  Frec Porcentual  Frec Acumulada
# 28    18           1           0.01              1.0               1
# 25    19           2           0.02              2.0               3
# 5     21           4           0.04              4.0               7
# 11    22           3           0.03              3.0              10
# 2     23           5           0.05              5.0              15
# 8     24           3           0.03              3.0              18
# 7     26           3           0.03              3.0              21
# 23    27           2           0.02              2.0              23
# 33    28           1           0.01              1.0              24
# 40    29           1           0.01              1.0              25
# 4     30           4           0.04              4.0              29
# 35    31           1           0.01              1.0              30
# 41    32           1           0.01              1.0              31
# ...

# %%
# Regla de Sturges
#  es una regla que sirve para calcular el numero de clases o intervalos idondeo en los que se debe dividir un conjunto de datos
# establece un numero de clases es igual a uno mas el logaritmo en base des del numero drotal de datos
# c = 1 + log2 (N)
# Donde N es el tamaño de la muestra

# %%
import math

# %%
#  volvemos a usar la lkista de edades
print (edades)
# Out:
# [30, 18, 39, 65, 54, 55, 69, 55, 27, 53, 29, 48, 21, 46, 40, 57, 33, 60, 48, 46, 19, 66, 58, 61, 57, 70, 55, 23, 59, 26, 41, 24, 64, 70, 70, 52, 23, 40, 37, 41, 70, 23, 60, 24, 30, 32, 49, 23, 30, 56, 21, 55, 24, 68, 40, 36, 57, 49, 53, 39, 30, 21, 55, 59, 54, 26, 53, 42, 21, 34, 54, 31, 19, 34, 56, 26, 22, 37, 22, 28, 22, 55, 45, 35, 23, 58, 51, 48, 35, 69, 43, 50, 64, 60, 55, 70, 69, 27, 47, 54]

# %%
# crear un data frame con las edades
df = pd.DataFrame ({'Edad': edades})
df
# Out:
#     Edad
# 0     30
# 1     18
# 2     39
# 3     65
# 4     54
# ..   ...
# 95    70
# 96    69
# 97    27
# 98    47
# 99    54
#
# [100 rows x 1 columns]

# %%
#  calcular el nuemro d eintervalos utilizando la regla de sturges
n = len (edades)
k= int (1+ math.log2(100))
print ( " Valor de n = ", n , "\n Número de intervalos = ", k)
# Out:
#  Valor de n =  100
#  Número de intervalos =  7

# %%
# crear la tabla de frecuencias
tabla_frecuencias = pd.cut (df['Edad'], bins = k, include_lowest=True ). value_counts().reset_index()
tabla_frecuencias.columns= ['Clase', 'Frec']
tabla_frecuencias
# Out:
#               Clase  Frec
# 0  (47.714, 55.143]    22
# 1  (17.947, 25.429]    18
# 2  (25.429, 32.857]    13
# 3  (32.857, 40.286]    13
# 4  (55.143, 62.571]    13
# 5    (62.571, 70.0]    13
# 6  (40.286, 47.714]     8

# %%
#  ordenar la tabla en base a las clases
# sort_values es el que ordena
tabla_frecuencias = tabla_frecuencias.sort_values (by= 'Clase')
tabla_frecuencias
# Out:
#               Clase  Frec
# 1  (17.947, 25.429]    18
# 2  (25.429, 32.857]    13
# 3  (32.857, 40.286]    13
# 6  (40.286, 47.714]     8
# 0  (47.714, 55.143]    22
# 4  (55.143, 62.571]    13
# 5    (62.571, 70.0]    13

# %%
# generar columnas siguientes
tabla_frecuencias['Frec Rel']= tabla_frecuencias ['Frec']/ n
tabla_frecuencias['Frec Porc']= tabla_frecuencias ['Frec']/ n * 100
tabla_frecuencias['Frec Ac']= tabla_frecuencias ['Frec'].cumsum()
tabla_frecuencias['Frec Rel Ac']= tabla_frecuencias ['Frec Rel'].cumsum()
tabla_frecuencias['Frec Porc Ac']= tabla_frecuencias ['Frec Porc'].cumsum()
#  Mostrar la atbal de frecuencias
print (tabla_frecuencias)
# Out:
#               Clase  Frec  Frec Rel  Frec Porc  Frec Ac  Frec Rel Ac  \
# 1  (17.947, 25.429]    18      0.18       18.0       18         0.18
# 2  (25.429, 32.857]    13      0.13       13.0       31         0.31
# 3  (32.857, 40.286]    13      0.13       13.0       44         0.44
# 6  (40.286, 47.714]     8      0.08        8.0       52         0.52
# 0  (47.714, 55.143]    22      0.22       22.0       74         0.74
# 4  (55.143, 62.571]    13      0.13       13.0       87         0.87
# 5    (62.571, 70.0]    13      0.13       13.0      100         1.00
#
#    Frec Porc Ac
# 1          18.0
# 2          31.0
# 3          44.0
# 6          52.0
# 0          74.0
# 4          87.0
# 5         100.0

# %%
import matplotlib.pyplot as plt
plt. hist(edades, alpha = 0.5)
plt.title("Histograma de edades basado en la función de matplotlib con valores estandar  ")
# Out:
# Text(0.5, 1.0, 'Histograma de edades basado en la función de matplotlib con valores estandar  ')

# %%
# crear un histograma basado en la gtablade frecuencia
plt.hist(df['Edad'], bins=k, alpha= 0.5 )
plt.title('Histograma de edades basado en la regla de sturges ')
plt.xlabel('Edades')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# ### Práctica 5 Diagrama de cajas y bigotes

# %%
import random
# lista, vector que representa la edad de 100 personas
edades2 =[]
# ciclo  para generar numeros aleatorios
for i in range (100):
  #generar el numero aleatorio con la funcion randit y se guarda en la variable numero_aleatorio
  numero_aleatorio= random.randint(20, 87)
# Agreganos el numero aleatorio a la lista de valores
  edades2.append(numero_aleatorio)
print (edades2)
# Out:
# [49, 65, 76, 70, 71, 31, 40, 68, 66, 77, 68, 53, 20, 41, 31, 27, 41, 32, 58, 23, 74, 30, 86, 34, 49, 84, 36, 27, 50, 29, 53, 53, 44, 22, 85, 39, 66, 83, 46, 87, 40, 54, 28, 29, 68, 57, 40, 41, 22, 57, 83, 42, 46, 54, 49, 81, 56, 37, 84, 42, 87, 36, 25, 85, 53, 81, 38, 83, 63, 81, 27, 76, 29, 83, 74, 25, 54, 52, 72, 53, 61, 42, 60, 66, 73, 46, 72, 54, 52, 53, 60, 34, 69, 71, 69, 71, 35, 83, 86, 71]

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(9,4))
bgplot1 = ax1.boxplot(edades, vert=True, patch_artist=True)
ax1.set_title('Edades encuesta 1')
bgplot2 = ax2.boxplot(edades2, vert=True, patch_artist=True)
ax2.set_title('Edades Encuesta 2')
plt.show()

# %%
edades2.append(130)

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(9,4))
bgplot1 = ax1.boxplot(edades, vert=True, patch_artist=True)
ax1.set_title('Edades encuesta 1')
bgplot2 = ax2.boxplot(edades2, vert=True, patch_artist=True)
ax2.set_title('Edades Encuesta 2')
plt.show()
