# %% [markdown]
# <a href="https://colab.research.google.com/github/AnahiGutierrez22/Estadistica/blob/main/Unidad1/Pr%C3%A1ctica6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# ##$Probabilidad$      $y$ $ estadística   $
#
# Unidad 1
#
# Practica 6. Estadística descriptiva de Dataset Autos
#
# Facilitador: Dr. José Gabriel Rodríguez Rivas
#
# Alumna: Anahí Gutiérrez López

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statistics as stats
import math

# %%
autos = pd.read_csv("autos2.csv", encoding="latin-1")

# %%
autos.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3              122.0  alfa-romero       gas        std
# 1          3              122.0  alfa-romero       gas        std
# 2          1              122.0  alfa-romero       gas        std
# 3          2              164.0         audi       gas        std
# 4          2              164.0         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# ...

# %%
autos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    float64
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       203 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %%
# Determinar el valor mínimo de precios
autos.price.min()
# Out:
# 5118.0

# %%
#Determinar el valor máximo de precios
autos.price.max()
# Out:
# 45400.0

# %%
#Determinar el valor de la moda de precios
moda = stats.mode(autos.price)
print(moda)
# Out:
# 16500.0

# %%
# Determinar la multimoda
multimoda = stats.multimode(autos.price)
print(multimoda)
# Out:
# [16500.0, 5572.0, 7957.0, 6229.0, 6692.0, 7609.0, 8921.0, 7295.0, 8845.0, 8495.0, 9279.0, 13499.0, 18150.0, 7775.0, 7898.0]

# %%
#Determinar el valor de la media de precios
media = np.mean(autos.price)
print (media)
# Out:
# 13207.129353233831

# %%
#Determinar el valor de la mediana de precios
mediana= stats.median(autos.price)
print (mediana)
# Out:
# 18150.0

# %%
#Determinar el valor de la desviación estándar de precios
desviacion_estandar= np.std(autos.price)
print(desviacion_estandar)
# Out:
# 7927.272870751157

# %%
#Determinar los estadísticos y cuartiles con la función describe()
autos.describe()
# Out:
#         symboling  normalized-losses  wheel-base      length       width  \
# count  205.000000         205.000000  205.000000  205.000000  205.000000
# mean     0.834146         122.000000   98.756585  174.049268   65.907805
# std      1.245307          31.681008    6.021776   12.337289    2.145204
# min     -2.000000          65.000000   86.600000  141.100000   60.300000
# 25%      0.000000         101.000000   94.500000  166.300000   64.100000
# 50%      1.000000         122.000000   97.000000  173.200000   65.500000
# 75%      2.000000         137.000000  102.400000  183.100000   66.900000
# max      3.000000         256.000000  120.900000  208.100000   72.300000
#
#            height  curb-weight  engine-size        bore      stroke  \
# count  205.000000   205.000000   205.000000  201.000000  201.000000
# mean    53.724878  2555.565854   126.907317    3.329751    3.255423
# std      2.443522   520.680204    41.642693    0.273539    0.316717
# ...

# %%
#Determinar mediante la regla de sturges la cantidad optima de bins o separadores
n = len(autos)
k= int (1+ math.log2(n))
print ( " Valor de n = ", n , "\n Número de intervalos = ", k)
# Out:
#  Valor de n =  205
#  Número de intervalos =  8

# %%
#Realizar un Histograma de precios de los automóviles
plt.hist(autos.price, bins=8, alpha=0.2, color='b', edgecolor = "black")
plt.axvline(media, color='b', linestyle= 'dashed', linewidth=2, label =f'Media: {media:.2f}')
plt.axvline(mediana, color='r', linestyle= 'dashed', linewidth=2, label = f'Mediana: {mediana:.2f}')
plt.axvline(moda, color='y', linestyle= 'dashed', linewidth=2, label =f'Moda: {moda:.2f}')
plt.axvline(desviacion_estandar, color='g', linestyle= 'dashed', linewidth=2, label =f'Desviación estandar: {desviacion_estandar:.2f}')
plt.legend()
plt.xlabel('Precio')
plt.ylabel('Frecuencia')
plt.title('Histograma de precios de los autos')
plt.show()

# %% [markdown]
# ##Conclusiones del histograma:
#
# En este histograma se puede observar primeramente los intervalos que calculamos con la regla de sturges que nos dio un total de 8 intervalos.
# en el eje ' x ' estan colocados los precios, en el eje ' y ' esta colocada frecuencia.
#
# Podemos observar en la primer linea punteada verde donde se encuentra la desviación estándar con un valor de 7927.27
#
# Enseguida en la linea azul punteada se encuentra la media con un valor de 13207.13
#
# Después esta la linea amarilla punteada que representa la moda con un valor de 16500
#
# Por último esta la linea roja punteada que nos muestra la mediana con un valor de 18150

# %%
#Realizar un diagrama de caja y bigotes que muestre la relación estadística entre la columna del precio del automóvil (price) y tipo de vehículo (body style)
sns.boxplot(x=autos['body-style'], y=autos['price'])
plt.title("Relación:  Tipo de vehiculo-Precio")
# Out:
# Text(0.5, 1.0, 'Relación:  Tipo de vehiculo-Precio')

# %% [markdown]
# ##Conclusiones del diagrama 1:
#
# En este diagrama de cajas y bigotes podemos observar en el eje ' x ' el body-style y en el eje ' y ' el precio.
#
# Las cajas azules representan donde se encuentra la mayoría de los datos, podemos observar que el primer tipo de auto 'convertible' la mayoria de los datos estan un po mas abajo de 15000 hasta un poco mas arriba de 30000, con un mínimo aproximadamente en 11000 y un máximo en 36 aprox.
#
# En el tipo ' hatchback' la mayoria de datos se encuentra un poco mas arriba de 5000 hasta aproximadamente los 12000, con un mínimo en 5000 y un máximo en 20000 con un dato saltante en 21000 aproximadamente.
#
# El 'sedan ' tiene sus datos agrupados entre los 7000 y los 18000 con un valor máximo en 5000 y un máximo en 32000, en este tipo slatan varios datos un poco fuera de lo comun a partir de los 32000 hasta los 42000 aprox.
#
# En la caja de 'wagon' los datos se encuentran entre los 8000 y los 15000, con un mínimo en 6000 y un máximo en 18000 aprox con un dato un poco usual en 28000.
#
# Por último en 'hardtop' los datos se encuentran entre los 9000 hasta los 32000, con un valor mínimo en 9000 y un valor máximo en los 45000.
#
# Nota : todos lo valores numericos son $ pero al ponerlo en el texto no se imprime como símbolo sino que cambia el tipo de letra.

# %%
#Realizar un diagrama de caja y bigotes que muestre la relación estadística entre la columna del precio del automóvil (price) y tipo tracción ruedas (drive wheels)
sns.boxplot(x=autos['drive-wheels'], y=autos['price'])
plt.title("Relación: Tipo de tracción-Precio")
# Out:
# Text(0.5, 1.0, 'Relación: Tipo de tracción-Precio')

# %% [markdown]
# ## Conclusiones del diagrama de bigotes 2:
#
# En este diagrama podemos observar la relación entre las ruedas de tracciones de los autos y el precio de los autos, tenemos tres tipos de tracción:
#
# La primera es la 'rwd' esta traccion se encuentra mas en los autos de un precio de entre los 12000 y los 22 aproximadamente, tiene un valor mínimo en 6000 y un valor máximo en 32000 y tiene unos datos que saltan a partir de 36000 hatsa los 45000.
#
# La segunda tracción 'fwd' se usa en autos con precios "bajos" entre los 6000  y los 10000 con un valor mínimo en 5000 y máximo en 16000, con datos que saltan desde los 16000 hasta los 25000.
#
# Por último la traccion '4wd' que esta muy cerca de la anterior con su mayoría de datos entre los  7000 y los  11000 con sus valores mínimos y máximos muy cercanos a estos valores con un fdato que salta en los 16000
#
# Nota : todos lo valores numericos son $ pero al ponerlo en el texto no se imprime como símbolo sino que cambia el tipo de letra.

# %%
#Realizar un diagrama de caja y bigotes que muestre la relación estadística entre la columna del precio del automóvil (price) y la ubicación del motor (engine-location)
sns.boxplot(x=autos['engine-location'], y=autos['price'])
plt.title("Relación: Ubicación del motor-Precio")
# Out:
# Text(0.5, 1.0, 'Relación: Ubicación del motor-Precio')

# %% [markdown]
# ## Conclusiones diagrama 3:
# En este último diagrama tenemos la relacion entre la ubicacion del motor en el eje ' x ' y el precio del auto en el eje ' y '.
#
# Primero tenemos el 'front ' que tiene la mayoría de sus valores entre los 7500 y los 16000 con un valor mínimo en 5000 y un valor máximo en 27000 aproximadamente con datos saltados entre los 30000 hasta los 45000.
#
# Y después esta 'rear' que tiene muy pocos datos entre los 34000 y los 36000 con sus valores mínimo y máximo muy cerca de donde estan sus datos conjuntos.
#
# Nota : todos lo valores numericos son $ pero al ponerlo en el texto no se imprime como símbolo sino que cambia el tipo de letra.

# %% [markdown]
# ##$ Conclusiones finales :$
# En esta última práctica de la unidad realicé un poco de todo lo que observamos en la primera unidad primero saqué las estadísticas descriptivas básicas y medidas de tendencia central, estas las logramos sacar con ayuda de las librerias que importamos al inicio de la práctica y tambien de cargar el documento proporcionado con los datos.
#  Las estadisticas anteriormente mecionadas que sacamos son la media, la moda, la mediana, tambien incluí la multimoda, ya que también aprendimos a sacarla, esta en caso de que existiera más de una.
#
#  Enseguida hice uso de tres funciones la primera -head()- para que mostrará las primeras 5 lineas de información del docuemnto y la segunda -info()- que nos sirve para mostrar lo que es mas importante de el documento proporcionado donde se ven los datos del contenidos y del total de registros que se tienen en este caso un total de 205 registros. La tercera fuencion fue la de -describe()- que nos sirve para determinar los estadisticos y los cuartiles de la información proporcionada.
#
#  Después hice uso del conocimiento previo para sacar el número dde intevalos con la regla de sturges, en esta práctica nos dio un resultado de 8 intervalos. Al tener lisa esta información de cuantpos bins utilizariamos realicé el histograma en donde se encontraban los precios es el eje' x ' y la frecuencia en el eje ' y ' en este histograma se señalaron las estadisticas descriptivas basicas y las medidas de tendencia central con lineas punteadas de diferentes colores.
#
#  Enseguida realicé los diagramas de cajas y bigotes para ver la relación que había entre ciertos aspectos de los autos y el precio.
#
#  El primer diagrama realizado fue de la relación del tipo de autos con el precio en donde se vieron 5 tipos de autos, en el diagrama se ven donde se encuentra la mayoria de los datos por tipo y precio.
#
#  En el segundo diagrama se observa la relación entre el tipo de tracción de las ruedas y el precio aqui se encuentran 3 tipos de tracción.
#
#  Por último se ve en el diagrama npumero 3 la relacion entre la ubicación del motor y el precio, en este caso solo se tienen dos tipos de motor y se observan las cajas donde se encuentran la mayoria de los datos.
#
#   Este trabajo fue importante para mí ya que fue como el paso final para poner en práctica todo lo visto y aprendido en clase, aparte de ver lo propio de la materia que es probabilidad y estadística tambien me ayudó en extender un poco más mis conocimientos en programación.
